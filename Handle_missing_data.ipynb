# %%
# Import packages and files
import pandas as pd
movies = pd.read_excel('Desktop/LSE-PYTHON_2/Data/movies.xlsx')
movies.head()
# Out:
#                             Title  Year  Age  IMDb  Rotten Tomatoes  \
# 0                       Inception  2010  13+   8.8             0.87
# 1                      The Matrix  1999  18+   8.7             0.87
# 2          Avengers: Infinity War  2018  13+   8.5             0.84
# 3              Back to the Future  1985   7+   8.5             0.96
# 4  The Good, the Bad and the Ugly  1966  18+   8.8             0.97
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# 1  Lana Wachowski,Lilly Wachowski                     Action,Sci-Fi
# 2         Anthony Russo,Joe Russo           Action,Adventure,Sci-Fi
# 3                 Robert Zemeckis           Adventure,Comedy,Sci-Fi
# 4                    Sergio Leone                           Western
#
#                         Country                 Language  Runtime
# 0  United States,United Kingdom  English,Japanese,French    148.0
# ...

# %%
# Import a file
ott = pd.read_csv('Desktop/LSE-PYTHON_2/Data/ott.csv')
ott.head()
# Out:
#    ID  Netflix  Hulu  Prime Video  Disney+
# 0   1        0     0            1        0
# 1   2        0     1            0        0
# 2   3        0     0            1        0
# 3   4        1     0            0        0
# 4   5        0     0            1        0

# %%
#Check the null values in specified column
movies['Age'].isnull().sum()
# Out:
# 9390

# %%
# Replace null values with "Others"
movies['Age'][movies['Age']. isna()] = "Others"
movies.tail()
# Out:
# /var/folders/6h/7phy_1_x4j90d_mv1z1dy8kc0000gn/T/ipykernel_17665/2139532959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['Age'][movies['Age']. isna()] = "Others"
#                            Title  Year     Age  IMDb  Rotten Tomatoes  \
# 16739  The Ghosts of Buxley Hall  1980  Others   6.2              NaN
# 16740             The Poof Point  2001      7+   4.7              NaN
# 16741      Sharks of Lost Island  2013  Others   5.7              NaN
# 16742         Man Among Cheetahs  2017  Others   6.6              NaN
# 16743           In Beaver Valley  1950  Others   NaN              NaN
#
#                   Directors                        Genres        Country  \
# 16739          Bruce Bilson  Comedy,Family,Fantasy,Horror  United States
# ...

# %%
#Replace null values with "Others"
movies['Directors'][movies['Directors'].isna()] = "Others"
movies['Genres'][movies['Genres'].isna()] = "Others"
movies['Country'][movies['Country'].isna()] = "Others"
movies['Language'][movies['Language']. isna()] = "Others"
movies.head()
# Out:
# /var/folders/6h/7phy_1_x4j90d_mv1z1dy8kc0000gn/T/ipykernel_17665/4028803571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['Directors'][movies['Directors'].isna()] = "Others"
# /var/folders/6h/7phy_1_x4j90d_mv1z1dy8kc0000gn/T/ipykernel_17665/4028803571.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['Genres'][movies['Genres'].isna()] = "Others"
# /var/folders/6h/7phy_1_x4j90d_mv1z1dy8kc0000gn/T/ipykernel_17665/4028803571.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Confirm if the code worked
movies['Directors'].isnull().sum()
# Out:
# 0

# %%
#Check the data type of columns
print(movies.dtypes)
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes    float64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object

# %%
# Replace null values with 0 as they are numeric values
movies = movies.fillna(0)
movies['Rotten Tomatoes'].fillna(0, inplace = True)
movies['Rotten Tomatoes'].isnull().sum()
# Out:
# 0

# %%
#Change the data type to integer 
movies['Rotten Tomatoes'] = movies['Rotten Tomatoes'].astype(float).astype(int)
print(movies.dtypes)
# Out:
# Title               object
# Year                 int64
# Age                 object
# IMDb               float64
# Rotten Tomatoes      int64
# Directors           object
# Genres              object
# Country             object
# Language            object
# Runtime            float64
# dtype: object
